# %% [markdown]
# # Importing libraries and reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv("weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# 4           W           41.0        ENE         NW           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# ...

# %%
df.shape
# Out:
# (142193, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  object
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Check for Duplicates and nan

# %%
print(f"The shape before Drop duplicates is {df.shape}")
print(f"Number of duplicates is {df.duplicated().sum()}")
df.drop_duplicates(ignore_index=True)
print(f"The shape after Drop duplicates is {df.shape}")
# Out:
# The shape before Drop duplicates is (142193, 24)
# Number of duplicates is 0
# The shape after Drop duplicates is (142193, 24)

# %%
#Null values in columns
print(f"The nan value of columns:\n {df.isna().sum().sort_values(ascending=False)}")
print('/'*50)
print(f"The percent of null value to the data: \n{(df.isna().sum()/len(df)).sort_values(ascending=False)}")
df.isna().sum().sort_values(ascending=False).plot(kind="bar")
# Out:
# The nan value of columns:
#  Sunshine         67816
# Evaporation      60843
# Cloud3pm         57094
# Cloud9am         53657
# Pressure9am      14014
# Pressure3pm      13981
# WindDir9am       10013
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir3pm        3778
# Humidity3pm       3610
# Temp3pm           2726
# WindSpeed3pm      2630
# Humidity9am       1774
# RainToday         1406
# Rainfall          1406
# WindSpeed9am      1348
# Temp9am            904
# MinTemp            637
# MaxTemp            322
# RISK_MM              0
# Date                 0
# Location             0
# RainTomorrow         0
# dtype: int64
# //////////////////////////////////////////////////
# The percent of null value to the data:
# Sunshine         0.476929
# Evaporation      0.427890
# Cloud3pm         0.401525
# Cloud9am         0.377353
# Pressure9am      0.098556
# Pressure3pm      0.098324
# WindDir9am       0.070418
# WindGustDir      0.065615
# WindGustSpeed    0.065193
# ...

# %%
#Drop column that has higg number of null values
df.drop(["Sunshine", "Evaporation", "Cloud3pm", "Cloud9am"],axis=1,inplace=True)

# %%
#Handle Nulls for obj_Column

# %%
obj_cols = df.select_dtypes(include="object").columns
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy="most_frequent")
df[obj_cols] = imputer.fit_transform(df[obj_cols])

# %%
obj_cols=df.select_dtypes(include="object").columns
for col in obj_cols:
    plt.figure(figsize=(10,8))
    sns.countplot(data=df,x=col)
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.scatterplot(x="Humidity3pm", y="Temp3pm", data=df)
# Out:
# <Axes: xlabel='Humidity3pm', ylabel='Temp3pm'>

# %%
sns.scatterplot(x="Pressure9am", y="Rainfall", data=df)
# Out:
# <Axes: xlabel='Pressure9am', ylabel='Rainfall'>

# %%
sns.lineplot(x="Date", y="Temp3pm", data=df)
# Out:
# <Axes: xlabel='Date', ylabel='Temp3pm'>

# %%
sns.lineplot(x="Date", y="Rainfall", data=df)
# Out:
# <Axes: xlabel='Date', ylabel='Rainfall'>

# %%
sns.boxplot(x="RainTomorrow", y="Humidity3pm", data=df)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='Humidity3pm'>

# %%
sns.countplot(x="RainTomorrow", hue="RainToday", data=df)
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='count'>

# %%
num_cols=df.select_dtypes(include="number").columns
for col in num_cols:
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    sns.boxplot(data=df,y=col)
    plt.title(f"Check the outlier for {col}")
    plt.subplot(1,2,2)
    sns.histplot(data=df,x=col,kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
from sklearn.impute import KNNImputer
num_cols = df.select_dtypes(include=["float64", "int64"]).columns

num_df = df[num_cols]

imputer = KNNImputer(n_neighbors=1) 
num_df_imputed = imputer.fit_transform(num_df)

num_df_imputed = pd.DataFrame(num_df_imputed, columns=num_cols, index=df.index)

df[num_cols] = num_df_imputed

# %% [markdown]
# ### Handle outliers

# %%
numeric_cols = df.select_dtypes(include="number")
bounds = {}
print(f"Data shape before removing outliers is {df.shape}")
for col in numeric_cols:
    if df[col].dropna().empty:
        continue

    q1 = np.percentile(df[col].dropna(), 25, interpolation='midpoint')
    q3 = np.percentile(df[col].dropna(), 75, interpolation='midpoint')
    iqr = q3 - q1

    low = q1 - 1.5 * iqr
    high = q3 + 1.5 * iqr

    bounds[col] = (low, high)

for col, (low, high) in bounds.items():
    df = df[(df[col] >= low) & (df[col] <= high)]

print(" Outliers removed. Final shape:", df.shape)
# Out:
# Data shape before removing outliers is (142193, 20)
#  Outliers removed. Final shape: (95857, 20)

# %%
plt.figure(figsize=(12,8))
num_cols=df.select_dtypes(include="number").columns
correlation=df[num_cols].corr()
sns.heatmap(data=correlation, cmap="coolwarm", annot=True)
plt.show()

# %% [markdown]
# ### Encoding data and feature engineering

# %%
df["Year"]=df["Date"].apply(lambda x: x.split('-')[0]).astype("int64")

# %%
#Create a season column
df["Month"]=df["Date"].apply(lambda x:x.split("-")[1]).astype("int64")
for val in df["Month"]:
    def get_season(month):
        if 3 <= month <= 6:
            return "Spring"
        elif 7 <= month <= 9:
            return "Summer"
        elif 10 <= month <= 11:
            return "Autumn"
        else:
            return "Winter"

df['Season'] = df['Month'].apply(get_season)

# %%
sns.boxplot(x="Month", y="Temp3pm", data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Temp3pm'>

# %%
# Replace country name with the median of raining days in the year
rain_days = df[df["RainToday"] == "Yes"]
unique_rain_days = rain_days[["Location", "Year", "Date"]].drop_duplicates()
rain_counts = unique_rain_days.groupby(["Location", "Year"]).size().reset_index(name="RainyDays")
avg_rain_per_location = rain_counts.groupby("Location")["RainyDays"].mean().round().astype(int)

df["Location"] = df["Location"].map(avg_rain_per_location)

# %%
df["WindSpeed_mean"] = df[["WindSpeed9am", "WindSpeed3pm"]].mean(axis=1)
df.drop(["WindSpeed9am", "WindSpeed3pm"], axis=1, inplace=True)

# %%
dir_map = {
    'N': 0, 'NNE': 22.5, 'NE': 45, 'ENE': 67.5,
    'E': 90, 'ESE': 112.5, 'SE': 135, 'SSE': 157.5,
    'S': 180, 'SSW': 202.5, 'SW': 225, 'WSW': 247.5,
    'W': 270, 'WNW': 292.5, 'NW': 315, 'NNW': 337.5
}


for col in ["WindGustDir", "WindDir9am", "WindDir3pm"]:
    df[col] = df[col].map(dir_map)

# %%
#Removing columns correlated together
df.drop( [
    "MinTemp",          
    "MaxTemp",          
    "Pressure9am",      
    "Temp9am",          
    "Date",
    "Year"           
],axis=1,inplace=True)

# %%
obj_cols=df.select_dtypes(include="object").columns
obj_cols
# Out:
# Index(['RainToday', 'RainTomorrow', 'Season'], dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(drop='first', sparse_output=False)

season_encoded = onehot_encoder.fit_transform(df[['Season']])
season_encoded_df = pd.DataFrame(season_encoded, 
                                 columns=onehot_encoder.get_feature_names_out(['Season']),
                                 index=df.index)

df.drop(columns=['Season'], inplace=True)
df = pd.concat([df, season_encoded_df], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
label_cols = ['RainToday', 'RainTomorrow']
le = LabelEncoder()

for col in label_cols:
    df[col] = le.fit_transform(df[col])

# %% [markdown]
# ### Split data

# %%
X=df.drop("RainTomorrow",axis=1,inplace=False)
y=df["RainTomorrow"]

# %% [markdown]
# ### Scaling data

# %%
from sklearn.preprocessing import StandardScaler
features = ['Location', 'Rainfall', 'WindGustDir', 'WindGustSpeed',
            'WindDir9am', 'WindDir3pm', 'Humidity9am', 'Humidity3pm',
            'Pressure3pm', 'Temp3pm', 'RainToday', 'RISK_MM',
            'Month', 'WindSpeed_mean', 'Season_Spring', 'Season_Summer', 'Season_Winter']

sc = StandardScaler()
X = sc.fit_transform(df[features])

# %% [markdown]
# ### Check balance in data and handle it

# %%
sns.countplot(data=df,x="RainTomorrow")
# Out:
# <Axes: xlabel='RainTomorrow', ylabel='count'>

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X, y = sm.fit_resample(X, y)

# %% [markdown]
# ### Prepare data for modeling

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=44,shuffle=True)
print(f"the shape of X train is {x_train.shape}")
print(f"the shape of X test is {x_test.shape}")
print(f"the shape of Y train is {y_train.shape}")
print(f"the shape of Y test is {y_test.shape}")
# Out:
# the shape of X train is (147308, 17)
# the shape of X test is (36828, 17)
# the shape of Y train is (147308,)
# the shape of Y test is (36828,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBRFClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score,classification_report,confusion_matrix

# %%
models = {
    "Logistic Regression":LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "XGBRF": XGBRFClassifier(use_label_encoder=False, eval_metric="mlogloss")
}

# %%
params = {
    "Logistic Regression":{},
    "Random Forest": {
        "n_estimators": [50, 100],
        "max_depth": [None, 10]
    },
    "Gradient Boosting": {
        "n_estimators": [50, 100],
        "learning_rate": [0.05, 0.1]
    },
    "AdaBoost": {
        "n_estimators": [50, 100,150],
        "learning_rate": [0.05, 0.1,.5]
    },
    "Decision Tree": {
        "max_depth": [5, 10,15],
        "min_samples_split": [2, 5,10]
    },
    "XGBRF": {
        "n_estimators": [50, 100,150],
        "max_depth": [3, 5,10,15]
    }
}

# %%
best_models = {}

for name in models:
    print(f"\nGrid Search for: {name}")
    
    grid = GridSearchCV(models[name], params[name], scoring='f1_macro', cv=3, n_jobs=-1)
    grid.fit(x_train, y_train)
    
    best_model = grid.best_estimator_
    y_pred = best_model.predict(x_test)
    
    print(f"Best Params: {grid.best_params_}")
    print(f"Accuracy:  {accuracy_score(y_test, y_pred):.4f}")
    print(f"Precision: {precision_score(y_test, y_pred, average='macro'):.4f}")
    print(f"Recall:    {recall_score(y_test, y_pred, average='macro'):.4f}")
    print(f"F1 Score:  {f1_score(y_test, y_pred, average='macro'):.4f}")
    
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    
    print("Confusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()
    

    best_models[name] = {
        "model": best_model,
        "params": grid.best_params_,
        "f1": f1_score(y_test, y_pred, average='macro')
    }
# Out:
# Grid Search for: Logistic Regression
# Best Params: {}
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1 Score:  1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18256
#            1       1.00      1.00      1.00     18572
#
#     accuracy                           1.00     36828
#    macro avg       1.00      1.00      1.00     36828
# weighted avg       1.00      1.00      1.00     36828
#
# Confusion Matrix:
# [[18256     0]
#  [    0 18572]]
# Grid Search for: Random Forest
# Best Params: {'max_depth': None, 'n_estimators': 50}
# Accuracy:  1.0000
# Precision: 1.0000
# Recall:    1.0000
# F1 Score:  1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18256
#            1       1.00      1.00      1.00     18572
#
#     accuracy                           1.00     36828
# ...

# %%
top_model = max(best_models, key=lambda name: best_models[name]["f1"])
print(f"\nBest Overall Model: {top_model}")
# Out:
# Best Overall Model: Logistic Regression

# %%
metrics_list = []

for model_name, info in best_models.items():
    model = info["model"]
    y_pred = model.predict(x_test)

    metrics_list.append({
        "Model": model_name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average='macro'),
        "Recall": recall_score(y_test, y_pred, average='macro'),
        "F1 Score": f1_score(y_test, y_pred, average='macro')
    })

# %%
results_df = pd.DataFrame(metrics_list)


results_melted = results_df.melt(id_vars="Model", var_name="Metric", value_name="Score")

plt.figure(figsize=(12, 6))
sns.barplot(data=results_melted, x="Model", y="Score", hue="Metric")
plt.xticks(rotation=45, ha="right")
plt.title("Model Performance Comparison")
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# %%
model = RandomForestClassifier(max_depth=None, n_estimators=50)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
with open("label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)
with open("onehot_encoder.pkl", "wb") as f:
    pickle.dump(onehot_encoder, f)
with open("scaler.pkl", "wb") as f:
    pickle.dump(sc, f)
